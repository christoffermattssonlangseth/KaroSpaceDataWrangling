# %%
import scanpy as sc
# Out:
# /Users/chrislangseth/miniforge3/envs/cellcharter/lib/python3.11/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
adata = sc.read_h5ad("/Users/chrislangseth/Downloads/muBrainRelease_seurat.h5ad")

# %%
adata.obs['sample_id'] = 'cosmx-mouse-brain'

# %%
adata.write('/Users/chrislangseth/Downloads/muBrainRelease_seurat.h5ad')

# %%
adata.obs.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_negprobes',
#        'nFeature_negprobes', 'fov', 'Area', 'AspectRatio', 'Width', 'Height',
#        'Mean.Histone', 'Max.Histone', 'Mean.G', 'Max.G', 'Mean.rRNA',
#        'Max.rRNA', 'Mean.GFAP', 'Max.GFAP', 'Mean.DAPI', 'Max.DAPI', 'cell_id',
#        'Run_Tissue_name', 'tissue', 'Panel', 'assay_type', 'slide_ID_numeric',
#        'cell_ID', 'unassignedTranscripts', 'nCount_falsecode',
#        'nFeature_falsecode', 'Area.um2', 'x_FOV_px', 'y_FOV_px', 'x_slide_mm',
#        'y_slide_mm', 'propNegative', 'complexity', 'errorCtEstimate',
#        'percOfDataFromError', 'qcFlagsRNACounts', 'qcFlagsCellCounts',
#        'qcFlagsCellPropNeg', 'qcFlagsCellComplex', 'qcFlagsCellArea',
#        'median_negprobes', 'negprobes_quantile_0.9', 'median_RNA',
#        'RNA_quantile_0.9', 'nCell', 'nCount', 'nCountPerCell',
#        'nFeaturePerCell', 'propNegativeCellAvg', 'complexityCellAvg',
# ...
