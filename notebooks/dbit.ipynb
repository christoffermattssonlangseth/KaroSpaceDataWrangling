# %%
import scanpy as sc
# Out:
# /Users/christoffer/miniconda3/envs/cellcharter310/lib/python3.10/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
RNA = sc.read_h5ad('/Volumes/processing/Bastien/DBiT/P22mousebrain_spatial_RNA_H3K27ac_RNAonly.h5ad')

# %%
epi = sc.read_h5ad('/Volumes/processing/Bastien/DBiT/P22mousebrain_spatial_RNA_H3K27ac_H3K27aconly.h5ad')

# %%
import numpy as np

# %%
RNA.obsm["X_umap"] = np.array(RNA.obs[['UMAP_1','UMAP_2']])

# %%
RNA.obs
# Out:
#                   orig.ident  nCount_Spatial  nFeature_Spatial  nCount_SCT  \
# CTAAGGTCACAAGCTA           0          5128.0              2037      3663.0
# CTAAGGTCTTGCTGGA           0          3105.0              1487      3120.0
# CTAAGGTCCTGTAGCC           0          4554.0              1837      3599.0
# CTAAGGTCAGTACAAG           0          2304.0              1035      2903.0
# CTAAGGTCAACAACCA           0          5359.0              2138      3695.0
# ...                      ...             ...               ...         ...
# GAACAGGCGATGAATC           0          3456.0              1570      3404.0
# GAACAGGCGCCAAGAC           0         14981.0              4227      3304.0
# GAACAGGCCGGAAGAA           0          5374.0              2155      3710.0
# GAACAGGCGTGACAAG           0          3826.0              1692      3540.0
# GAACAGGCGAACCAGA           0          5130.0              2040      3638.0
#
#                   nFeature_SCT  nCount_H3K27ac  nFeature_H3K27ac  \
# ...

# %%
sc.pl.umap(RNA, color = ['RNA_clusters','H3K27ac_clusters'])

# %%
epi.X.max()
# Out:
# np.float64(6.84571)

# %%
RNA.X.max()
# Out:
# np.float64(5.83773044716594)

# %%
RNA
