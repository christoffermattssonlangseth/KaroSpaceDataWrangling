# %%
import scanpy as sc
# Out:
# /Users/chrislangseth/miniforge3/envs/cellcharter/lib/python3.11/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
ad = sc.read_h5ad('/Users/chrislangseth/Downloads/Human_VisiumHD_compressed_v1.companion.ready.h5ad')

# %%
ad[ad.obs.module_label.notna()].obs.Final_celltype.value_counts()
# Out:
# Final_celltype
# Microglia    2263
# Name: count, dtype: int64

# %%
ad[ad.obs.module_label.isna()].obs.Final_celltype.value_counts()
# Out:
# Final_celltype
# Excitatory Neuron     23827
# Astrocytes            19800
# Oligodendrocytes      18959
# Granule neuron CBL    11444
# Inhibitory Neuron      3641
# Tumor                  3279
# Bergmann glia CBL      3262
# PC CBL                 2562
# Schwann cells          1326
# MDM                    1266
# Pericytes               932
# OPC                     758
# Erythrocytes            716
# Endothelial cells       700
# Dysmorphic neurons      476
# Fibroblasts             434
# Plasmablasts            256
# SMC                     254
# CD4 TRM                 202
# CD8 TRM                  29
# CAM                      23
# Name: count, dtype: int64

# %%
import numpy as np

# %%
ad.obsm['spatial'] = np.array(ad.obsm['spatial'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ad.obsm['spatial'] = np.array(ad.obsm['spatial'])
#
# File ~/miniforge3/envs/cellcharter/lib/python3.11/site-packages/anndata/_core/aligned_mapping.py:215, in AlignedActual.__getitem__(self, key)
#     214 def __getitem__(self, key: str) -> Value:
# --> 215     return self._data[key]
#
# KeyError: 'spatial'

# %%
ad.write('/Users/chrislangseth/Downloads/GSE284005_merfish_all.h5ad')

# %%
ad
# Out:
# AnnData object with n_obs × n_vars = 401794 × 500
#     obs: 'nCount_Vizgen', 'nFeature_Vizgen', 'z', 'volume', 'fov', 'cell', 'sample', 'x', 'y', 'majorCluster_final', 'Region_banksy', 'Region_banksy_major'
#     uns: 'X_name'
#     obsm: 'spatial'
#     layers: 'counts'
