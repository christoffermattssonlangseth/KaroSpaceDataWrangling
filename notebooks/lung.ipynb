# %%
import scanpy as sc
import numpy as np

# %%
adata = sc.read_h5ad('/Users/chrislangseth/Downloads/ISS_objects_final_publication_for_reproducibility/adata_16samples_clustered_log_annotated_curated_notln_adata4_211123_with_colors_&refined.h5ad')
# Out:
# /Users/chrislangseth/miniforge3/envs/cellcharter/lib/python3.11/site-packages/anndata/_core/anndata.py:1806: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata.obsm['spatial'] = np.array(adata.obs[['x', 'y']])

# %%
adata.write('/Users/chrislangseth/Downloads/ISS_objects_final_publication_for_reproducibility/adata_16samples_clustered_log_annotated_curated_notln_adata4_211123_with_colors_&refined.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 260398 × 159
#     obs: 'cell', 'x', 'y', 'cluster', 'n_transcripts', 'density', 'elongation', 'area', 'avg_confidence', 'sample', 'region', 'n_genes', 'n_counts', 'counts_markers', 'leiden2', 'ID', 'celltype_annotated_refined', 'celltype_annotated_general', 'level3', 'level2', 'level1', 'celltype_annotated_collapsed', 'X', 'Y', 'position', 'cell_class', 'celltype_annotated_general_dotplot'
#     uns: 'cell_class_colors', 'celltype_annotated_collapsed_colors', 'celltype_annotated_general_colors', 'celltype_annotated_refined_colors', 'dendrogram_celltype_annotated_general', 'dendrogram_leiden', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups', 't-test', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     obsp: 'connectivities', 'distances'

# %%
adata2 = sc.read_h5ad('/Users/chrislangseth/Downloads/ISS_objects_final_publication_for_reproducibility/niches_analysis_COPD_SCRINSHOT_180624.h5ad')

# %%
adata2.obsm
# Out:
# AxisArrays with keys: X_umap, spatial
