# %%
import scanpy as sc

# %%
ad = sc.read_h5ad("/Users/chrislangseth/Downloads/HS_GM_Ctrl_multiomics_UCSC_final.h5ad")

# %%
ad
# Out:
# AnnData object with n_obs × n_vars = 5475 × 36601
# ...

# %%
import numpy as np
ad.obs.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'nCount_ATAC',
#        'nFeature_ATAC', 'nucleosome_signal', 'nucleosome_percentile',
#        'TSS.enrichment', 'TSS.percentile', 'sample', 'lesion', 'patient',
#        'region', 'broadcelltypes', 'pct_chrY', 'pct_chrX', 'CHRY_K2',
#        'CHRY_K3', 'CHRX_K2', 'nCount_peaks', 'nFeature_peaks',
#        'nCount_ACTIVITY', 'nFeature_ACTIVITY', 'fragments', 'FRiP',
#        'blacklist_fraction', 'RNA_snn_res.0.8', 'seurat_clusters',
#        'RNA.weight', 'ATAC.weight', 'wsnn_res.0.8', 'predicted.id',
#        'prediction.score.COPs', 'prediction.score.Neuron1',
#        'prediction.score.Neuron2', 'prediction.score.Neuron3',
#        'prediction.score.Oligo2', 'prediction.score.Astrocytes',
#        'prediction.score.Oligo6', 'prediction.score.Oligo1',
#        'prediction.score.Oligo4', 'prediction.score.Oligo3',
#        'prediction.score.Pericytes', 'prediction.score.Neuron4',
# ...

# %%
sc.pl.embedding(ad,  basis = 'umap.harmony', color ='predicted.id')
