# %%
import scanpy as sc
# Out:
# /Users/chrislangseth/miniforge3/envs/cellcharter/lib/python3.11/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
ad = sc.read_h5ad('/Volumes/processing/cellxgene/cellxgene_visium/Single-cell_and_spatial_transcriptomics_characterisation_of_the_immunological_la/7a90a1ce-4e66-44d0-b273-7c672de53b17.h5ad')

# %%
ad.obs.disease
# Out:
# AAACAACGAATAGTTC-1    primary sclerosing cholangitis
# AAACAAGTATCTCCCA-1    primary sclerosing cholangitis
# AAACAATCTACTAGCA-1    primary sclerosing cholangitis
# AAACACCAATAACTGC-1    primary sclerosing cholangitis
# AAACAGAGCGACTCCT-1    primary sclerosing cholangitis
#                                    ...
# TTGTTTCACATCCAGG-1    primary sclerosing cholangitis
# TTGTTTCATTAGTCTA-1    primary sclerosing cholangitis
# TTGTTTCCATACAACT-1    primary sclerosing cholangitis
# TTGTTTGTATTACACG-1    primary sclerosing cholangitis
# TTGTTTGTGTAAATTC-1    primary sclerosing cholangitis
# Name: disease, Length: 4992, dtype: category
# Categories (1, object): ['primary sclerosing cholangitis']

# %%
import sys
sys.path.append("/Users/chrislangseth/work/karolinska_institutet/projects/BaloMS/")
from utils import spatial_utils

spatial_utils.plot_spatial_compact_fast(
    ad[ad.obs['in_tissue']==1],
    color="cell_type",
    groupby="donor_id",
    spot_size=10,
    cols=1,
    height=10,
    background="white",
    dpi=120,
)
